# %%
# !pip install llama-index pypdf sentence_transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.4/609.4 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.1/256.1 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 24.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.5 MB/s eta 0:00:00
# ...

# %% [markdown]
#  LlamaIndex contains a toolkit designed to easily connect LLM’s with your external data.
#
# Creating and Quering Index
#
# Saving and Loading Index
#
# Customize LLM
#
# Customize Prompt
#
# Customize Embedding

# %%
# !pip install openai

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import openai
openai.api_key = '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'
os.environ["OPENAI_API_KEY"] = "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"

# %%
# !pip install llama_index

# %%
import os

from llama_index import VectorStoreIndex, SimpleDirectoryReader

# Get the path to the directory where the Google patent text files are stored
patent_files_path = os.path.join('/content/drive/MyDrive/Colab Notebooks/patents/AllPatentTextDocs')

# Create a reader that will read the Google patent text files
reader = SimpleDirectoryReader(patent_files_path)

# Load the text of the Google patent text files
documents = reader.load_data()

# Create a vector store index from the documents
index = VectorStoreIndex.from_documents(documents)

# Create a query engine from the index
query_engine = index.as_query_engine()

# %%
response = query_engine.query("What is this US10048858 about?")
print(response)
# Out:
# This US10048858 is about a method for providing a user interface of a mobile communication terminal having a tap sensitive sensor and a display. The method includes detecting a first tap in a first direction of the mobile terminal using the tap sensitive sensor, determining a first user input utilizing the first tap in the first direction, and as a response to the first user input executing a first set of software code corresponding to the first user input and serving to control at least one display related aspect of the mobile communication terminal. The first set of software code may comprise code for illuminating the display, rendering a first exercise related measurement on the display, and generating synthetic voice sounds at least in part corresponding to at least part of data of the display.

# %%
response = query_engine.query("title of US10048858")
print(response)
# Out:
# The title of US10048858 is "Method and Apparatus for Controlling a Mobile Device".

# %%
response = query_engine.query("give me any similar of this US10728521 google patents is present")
print(response)
# Out:
# US10450090 - Social Network Interaction System

# %% [markdown]
# Saving and Loading Index

# %%
index.storage_context.persist("naval_index")

# %%
from llama_index import StorageContext, load_index_from_storage

# rebuild storage context
storage_context = StorageContext.from_defaults(persist_dir="naval_index")
# load index
new_index = load_index_from_storage(storage_context)

# %%
new_query_engine = new_index.as_query_engine()
response = new_query_engine.query("Explain about US10728521?")
print(response)
# Out:
# US10728521 is a patent for a system and method for providing a user interface for a mobile device. The system includes a display and user input for a mobile device that provides a set of icons or other user selectable objects in a number of different idle mode screens. The user interface has two modes: a focused mode, in which the user input can change focus so that the user can focus and select a desired object from a presented idle mode screen; and a non-focused mode, in which none of the objects is focused. Instead of changing the focus from one object to another, the user input can change the idle mode screen itself so that different predefined contents can be accessed with a limited user input. The controller is also capable of enabling or disabling the access to the non-focused mode, and can change the operation of the device from focused mode to non-focused mode responsive to detecting an idle period in user interaction meeting a predetermined threshold interval.

# %% [markdown]
# Customizing LLM's

# %%
from llama_index import LLMPredictor, ServiceContext

from langchain.chat_models import ChatOpenAI

llm_predictor = LLMPredictor(llm=ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo"))

service_context = ServiceContext.from_defaults(llm_predictor=llm_predictor)

custom_llm_index = VectorStoreIndex.from_documents(
    documents, service_context=service_context
)

# %%
custom_llm_query_engine = custom_llm_index.as_query_engine()
response = custom_llm_query_engine.query("give me any similar of this US10728521 google patents is present")
print(response)
# Out:
# Based on the provided context information, there is no mention of the patent number US10728521 or any similar patents in the given information.

# %% [markdown]
# Custom Prompt

# %%
from llama_index import Prompt

template = (
    "We have provided context information below. \n"
    "---------------------\n"
    "{context_str}"
    "\n---------------------\n"
    "Given this information, please answer the question and each answer should start with code word AI Demos: {query_str}\n"
)
qa_template = Prompt(template)

# %%
query_engine = custom_llm_index.as_query_engine(text_qa_template=qa_template)
response = query_engine.query("Give me any similar of this US10728521 google patents is present")
print(response)
# Out:
# AI Demos: I'm sorry, but I cannot browse the internet or access specific patent databases. I can only provide information based on the context you have provided.

# %% [markdown]
# Custom Embedding

# %%
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index import LangchainEmbedding, ServiceContext

# load in HF embedding model from langchain
embed_model = LangchainEmbedding(HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2'))
service_context = ServiceContext.from_defaults(embed_model=embed_model)

new_index = VectorStoreIndex.from_documents(
    documents,
    service_context=service_context,
)

# %%
query_engine = new_index.as_query_engine()
response = query_engine.query("US10450090")
print(response)
# Out:
# US10450090 is a patent related to a system for providing a user with a secure log-on to a computer system. The system includes a secure log-on server, a secure log-on client, and a secure log-on database. The secure log-on server is configured to receive a user's log-on information and to authenticate the user's log-on information. The secure log-on client is configured to receive the user's log-on information and to transmit the user's log-on information to the secure log-on server. The secure log-on database is configured to store the user's log-on information and to provide the secure log-on server with the user's log-on information.

# %%
query_engine = new_index.as_query_engine()
response = query_engine.query("Give me the summary of US10728521")
print(response)
# Out:
# SUMMARY: US10728521 discloses a method and system of communication using an extended sequence number. The method includes receiving a network authentication token with a first message authentication code, an authentication message field, and a first extended sequence number that includes a first hardware identifier and first sequence number. The network is authenticated based on the first message authentication code, the first hardware identifier, and the first sequence number. The method also includes extracting the first message authentication code and the first extended sequence number from the network authentication token, calculating a second message authentication code based on the random number, the first extended sequence number, and a key stored in the mobile equipment, and authenticating the network if the first message authentication code matches the second message authentication code, the first hardware identifier matches the second hardware identifier, and the first sequ
# ...

# %%
query_engine = new_index.as_query_engine()
response = query_engine.query("Which google patent is explaining about a computer program for omnidirectional video")
print(response)
# Out:
# The patent that is explaining about a computer program for omnidirectional video is US11172208, titled "Method and Apparatus for Improving the Visual Quality of Viewport-Based Omnidirectional Video Streaming".
